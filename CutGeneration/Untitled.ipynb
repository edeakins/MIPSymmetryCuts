# %%
from gurobipy import *

# %%
m = read("../jim_instances/codbt06.mps")
m.setParam("TimeLimit", 41.56)
for var in m.getVars():
    var.vType = GRB.INTEGER
m.update()
m.optimize()
# Out:
# Read MPS format model from file ../jim_instances/codbt06.mps
# Reading time = 0.00 seconds
# : 729 rows, 729 columns, 9477 nonzeros
# Changed value of parameter TimeLimit to 41.56
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (linux64)
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
# Optimize a model with 729 rows, 729 columns and 9477 nonzeros
# Model fingerprint: 0x244ead1c
# Variable types: 0 continuous, 729 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 243.0000000
# Presolve time: 0.00s
# Presolved: 729 rows, 729 columns, 9477 nonzeros
# Variable types: 0 continuous, 729 integer (729 binary)
#
# Root relaxation: objective 5.607692e+01, 3602 iterations, 0.98 seconds
#
# ...

# %%
m = read("testSi.lp")
m.setParam("TimeLimit", 746.5)
# for i in range(len(m.getConstrs())):
#     if i >= 120:
#         m.getConstrs()[i].lazy = 1
#         m.update()
# #     print(m.getConstrs()[i].lazy)
# m.write("test.lp")
# r = m.relax()
# r.optimize()
# for var in r.getVars():
#     print(var.varName, "=", var.x)
# for con in r.getConstrs():
#     print(con.constrName, "status:", con.cBasis, "slack:", con.slack)
    
m.optimize()
for var in m.getVars():
    print(var.varName, "=", var.x)
# Out:
# Read LP format model from file testSi.lp
# Reading time = 0.28 seconds
# OBJROW: 1872 rows, 729 columns, 842724 nonzeros
# Changed value of parameter TimeLimit to 746.5
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (linux64)
# Thread count: 12 physical cores, 24 logical processors, using up to 24 threads
# Optimize a model with 1872 rows, 729 columns and 842724 nonzeros
# Model fingerprint: 0xf3424560
# Variable types: 0 continuous, 729 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e-02, 5e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+04]
# Found heuristic solution: objective 243.0000000
# Presolve added 234 rows and 235 columns
# Presolve time: 1.05s
# Presolved: 2106 rows, 964 columns, 683829 nonzeros
# Variable types: 0 continuous, 964 integer (729 binary)
#
# Root simplex log...
#
# ...
